# %% [markdown]
# ## Pandas
# ## ¿Qué es?
# Pandas es una biblioteca de código abierto que nos porporciona estructuras y herramientas  para poder procesar nuestros datos y analizarlos de forma simple.
# Visita la documentación [aquí][doc]
#
#
#
# [doc]:https://pandas.pydata.org

# %% [markdown]
# ## Importación de las biblioteccas

# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import seaborn as sns

# %% [markdown]
# ## [Series][docSeries]
# Las series son matrices unidimensionales capaces de contener cualquier tipo de datos.
# * Las etiquetas se denominan índices
# * Es como una columna de Excel
#
# Para crear una serie se hace lo siguiente, recibe como parámetro un array, iterable, diccionario o escalar. Los ejemplos se presentan a continuación:
# ### Creación de series
# #### A partir de un array de numpy, lista o tupla
#
#
# [docSeries]:https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html

# %%
serie=pd.Series(np.array([3,2]))
#print(serie)
print(serie)
# Out:
# 0    3
# 1    2
# dtype: int32

# %% [markdown]
# #### Con diccionario

# %%
d1 = { "a": 10, "b": 20, "c": 40 }
serie2 = pd.Series(d1)
print(serie2)
# Out:
# a    10
# b    20
# c    40
# dtype: int64

# %% [markdown]
# #### Colocando índices

# %%
serie=pd.Series([1,2,3,4,5,6], index=["a","b","c","d","e","f"])
#print(serie)
print(serie[["a","c"]])
# Out:
# a    1
# c    3
# dtype: int64

# %%
serieA=pd.Series(range(1,100,2))
serieA.tail()
# Out:
# 45    91
# 46    93
# 47    95
# 48    97
# 49    99
# dtype: int64

# %% [markdown]
# ### Manipulación de series

# %% [markdown]
# #### Métodos head(), tail() o sample()
# Estos métodos nos permiten obtener cuerto número de nuestra serie de la siguiente manera:
# - head(n): Retorna los primeros n valores de la serie. Por defecto regresa 5
# - tail(n): Retorna los últimos n valores de la serie. Por defecto regresa 5
# - sample(n): Retorna una muestra aleatoria de n valores en nuestros datos

# %%
serieA.head()
#serieA.tail()
#serieA.sample(10)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %% [markdown]
# #### Obtener un elemento
# Para obtener un elemento de la serie, solo hay que hacer referencia por su índice

# %%
print(serie["a"])
# Out:
# 1

# %% [markdown]
# ####  Promedio, mínimo o máximo de una serie
#
# Para obtener estos valores se tienen los sguientes métodos:
#    - mean(): El valor promedio de toda la serie
#    - max(): El valor máximo de toda la serie
#    - min(): El valor mínimo de toda la serie

# %%
print(serieA.mean())
# Out:
# 50.0

# %% [markdown]
# ## [DataFrame][docDataFrame]
# Son estructuras de datos bidimensionales de tamaño variable y potencialmente heterogénea con datos etiquetados.
#
# Para crear un DataFrame tenemos las siguientes opciones
#
# [docDataFrame]:https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %%
frame=pd.DataFrame([0,1,2,3,4])
frame.head()
# Out:
#    0
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# #### Con diccionario

# %%
diccionario={
    "id":[1,2,3],
    "persona":["Lara","Enrique","Victor"],
    "Calificacion":[0,10,10],
    "Estado":["Reprobado","Aprobado","Aprobado"]
}
frameDic=pd.DataFrame(diccionario)
frameDic.set_index(["id"],inplace=True)
frameDic.tail()
# Out:
#     persona  Calificacion     Estado
# id
# 1      Lara             0  Reprobado
# 2   Enrique            10   Aprobado
# 3    Victor            10   Aprobado

# %% [markdown]
# ## Leer un archivo CSV

# %%
dataCSV=pd.read_csv("housing.csv")
dataCSV.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ## Informacion del DataFrame

# %%
dataCSV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Descripcion del DataFrame

# %%
dataCSV.describe() #Numericos
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
dataCSV.describe(include = ["object", "bool"])
# Out:
#        ocean_proximity
# count            20640
# unique               5
# top          <1H OCEAN
# freq              9136

# %% [markdown]
# ## Renombrar una columna

# %%
frame.rename(
    columns={0:"nuevoNombre"}, 
    #inplace=True
).head()
# Out:
#    nuevoNombre
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4

# %%
frame.head()
# Out:
#    0
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# #### Eliminar una columna

# %%
dataCSV.drop("ocean_proximity",inplace=True,axis=1)
dataCSV.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %% [markdown]
# #### Seleccionar columna

# %%
dataCSV[["longitude","latitude"]].head()
# Out:
#    longitude  latitude
# 0    -122.23     37.88
# 1    -122.22     37.86
# 2    -122.24     37.85
# 3    -122.25     37.85
# 4    -122.25     37.85

# %% [markdown]
# #### Seleccionar fila y columna

# %%
dataCSV.loc[[1,9],["longitude","latitude"]].head()
# Out:
#    longitude  latitude
# 1    -122.22     37.86
# 9    -122.25     37.84

# %%
dataCSV.loc[0:35, "housing_median_age":].head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                41.0        880.0           129.0       322.0       126.0
# 1                21.0       7099.0          1106.0      2401.0      1138.0
# 2                52.0       1467.0           190.0       496.0       177.0
# 3                52.0       1274.0           235.0       558.0       219.0
# 4                52.0       1627.0           280.0       565.0       259.0
#
#    median_income  median_house_value
# 0         8.3252            452600.0
# 1         8.3014            358500.0
# 2         7.2574            352100.0
# 3         5.6431            341300.0
# 4         3.8462            342200.0

# %%
dataCSV.iloc[15:20,1:3]
# Out:
#     latitude  housing_median_age
# 15     37.85                50.0
# 16     37.85                52.0
# 17     37.85                52.0
# 18     37.84                50.0
# 19     37.84                52.0

# %% [markdown]
# #### Limpieza de un dataset
# ##### Resumen rápido de un DataFrame

# %%
dataCSV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# ##### ¿Hay nulos?

# %%
dataCSV.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %% [markdown]
# ##### ¿Cómo los vamos a tratar?
# Conseguir datos es un trabajo realmente difícil y costoso por lo que optar por eliminarlos a veces no es la mejor opción. Esto depende del problema. Algunas alternativas a eliminarlos son:
# - Colocar el valor promedio
# - Colocar la moda
# - Colocar el valor mínimo
# - Colocar el valor máximo

# %%
dataCSV["total_bedrooms"].fillna(value=dataCSV["total_bedrooms"].mean())
dataCSV.info()
#dataCSV["total_bedrooms"].dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# ## Ordenar valores

# %%
dataCSV.sort_values(by="median_house_value", ascending=True, inplace=True)
dataCSV.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9188     -117.86     34.24                52.0        803.0           267.0
# 2799     -117.02     36.40                19.0        619.0           239.0
# 2521     -122.74     39.71                16.0        255.0            73.0
# 19802    -123.17     40.31                36.0         98.0            28.0
# 5887     -118.33     34.15                39.0        493.0           168.0
#
#        population  households  median_income  median_house_value
# 9188        628.0       225.0         4.1932             14999.0
# 2799        490.0       164.0         2.1000             14999.0
# 2521         85.0        38.0         1.6607             14999.0
# 19802        18.0         8.0         0.5360             14999.0
# 5887        259.0       138.0         2.3667             17500.0

# %%
dataCSV.loc[[0,1]]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0

# %%
dataCSV.iloc[0:2]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9188    -117.86     34.24                52.0        803.0           267.0
# 2799    -117.02     36.40                19.0        619.0           239.0
#
#       population  households  median_income  median_house_value
# 9188       628.0       225.0         4.1932             14999.0
# 2799       490.0       164.0         2.1000             14999.0

# %% [markdown]
# ## Filtrando datos

# %%
dataCSV[dataCSV["median_house_value"] >= dataCSV["median_house_value"].mean()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8385 entries, 3915 to 17118
# Data columns (total 9 columns):
# longitude             8385 non-null float64
# latitude              8385 non-null float64
# housing_median_age    8385 non-null float64
# total_rooms           8385 non-null float64
# total_bedrooms        8300 non-null float64
# population            8385 non-null float64
# households            8385 non-null float64
# median_income         8385 non-null float64
# median_house_value    8385 non-null float64
# dtypes: float64(9)
# memory usage: 655.1 KB

# %% [markdown]
# ## Histograma del DataFrame

# %%
dataCSV.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E76F30C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E776256D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77657978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77687F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E776C0518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E776EEAC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E777280B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E777566A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E777566D8>]],
#       dtype=object)

# %% [markdown]
# ## Correlaciones

# %%
correlaciones = dataCSV[dataCSV.columns].corr()
correlaciones
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %%
sns.heatmap(correlaciones)

# %%
scatter_matrix(dataCSV[dataCSV.columns], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E779AB898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E780F6F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77B85438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77BB59E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77BE8F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77C27588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77C56B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77C95160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77C95198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77CF9C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77D35278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77D687F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77D9ADA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77DD9390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77E08940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77E3BEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77E794E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77EAAA90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E77EE8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78519630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7854BBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7858A1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E785B8780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E785EED30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7862A320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7865A8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7868DE80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E786CA470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E786FBA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78730FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7876A5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7879DB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E787DA160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7880C710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7883ECC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7887D2B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E788AD860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E788E0E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7891C400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E7894E9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78980F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E789BE550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E789EEB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78A300F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78A5E6A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78A90C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78ACF240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78B007F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78B31DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78B71390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78BA1940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78BD5EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78C104E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78C41A90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78C80080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78CB2630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78CE1BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78D201D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78D50780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78D83D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78DC2320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78DF28D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78E26E80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78E64470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78E96A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78EC5FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78F035C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78F33B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78F74160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78FA4710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E78FD8CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E790142B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000023E79046860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E79075E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E790B4400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E790E49B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E79118F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E79157550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E79189B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E791C70F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023E791F66A0>]],
#       dtype=object)

# %% [markdown]
# ## Exportar CSV

# %%
dataCSV.to_csv("nuevo_housing.csv")
